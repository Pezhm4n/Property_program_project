# %%
# !pip install PyQt5 pandas matplotlib numpy seaborn xlsxwriter reportlab
# Out:
# ...
#   Using cached XlsxWriter-3.2.3-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached reportlab-4.4.0-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (552 bytes)
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.9 MB 2.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.0/6.9 MB 3.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.9/6.9 MB 4.8 MB/s eta 0:00:01
#    --------------------------- ------------ 4.7/6.9 MB 5.9 MB/s eta 0:00:01
#    --------------------------------- ------ 5.8/6.9 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.9 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 5.1 MB/s eta 0:00:00
# ...
